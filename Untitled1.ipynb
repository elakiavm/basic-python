# %%
num1 = 36
num2 = 6

sum = num1 % num2 

print("The sum of {},{} result {}" .format(num1 ,num2 ,sum))
# Out:
# The sum of 36,6 result 0

# %%
a = 100

if a<100 :
    print("a is lesser than 100")
    
elif a==100:
    print("a is equal to 100 ")
else:
    print("a is greater than 100")
# Out:
# a is equal to 100
